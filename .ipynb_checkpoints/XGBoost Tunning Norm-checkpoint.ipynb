# %% [markdown]
# # XGBoost Tunning
#
#
# Load Libraries

# %%
# %matplotlib inline
import sys, os
import numpy as np
import xgboost as xgb
import seaborn as sns
import pandas as pd

from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.cross_validation import train_test_split
from scipy import stats

import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

sns.set(font_scale = 1.5)
# Out:
# /Users/andrescala/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Load data and preprocess

# %%
data = pd.read_csv('data/cs-training.csv').drop('id', axis = 1).fillna(0)

target = data['SeriousDlqin2yrs'].astype('int')
data = data.drop(['SeriousDlqin2yrs'],axis=1)

#min_max_scaler = preprocessing.MinMaxScaler()
#x_scaled = min_max_scaler.fit_transform(data)
#normalized_data = pd.DataFrame(x_scaled)
#train_data, test_data, train_target, test_target  = train_test_split(normalized_data, target, test_size=0.3)

#train_data.to_csv('gen_data/dataTrain.csv', sep=',', encoding='utf-8')
#test_data.to_csv('gen_data/dataTest.csv', sep=',', encoding='utf-8')

#print(train_data.shape)
#print(train_target.shape)
#print(test_data.shape)
#print(test_target.shape)

# %% [markdown]
# # PCA

# %%
sScaler = StandardScaler(copy=True, with_mean=True, with_std=True)

xScaled = sScaler.fit_transform(data)

forPca = pd.DataFrame(xScaled)

pca = PCA(n_components=9)

xPca = pca.fit_transform(data)
print(xPca.shape)
xPcaDataframe = pd.DataFrame(xPca, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9'])

xPcaDataframe['cat'] = target

print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_))

train_data, test_data, train_target, test_target  = train_test_split(xPca, target, test_size=0.3)
# Out:
# (150000, 9)
# explained variance ratio (first two components): [  9.76329027e-01   2.33172724e-02   3.52014429e-04   1.23603626e-06
#    2.91823184e-07   1.44122684e-07   6.76723150e-09   5.33806324e-09
#    1.69928564e-09]

# %%
ax = sns.lmplot(data = xPcaDataframe, x='PC2', y='PC1', hue='cat', size=10, aspect=20, fit_reg=False,
               scatter_kws={'alpha': 0.3})
fig = plt.gcf()
fig.set_size_inches(15, 7)

# %% [markdown]
# ### Converting data for XGBoost

# %%
#dataPredict = dataPredict.drop(['SeriousDlqin2yrs'],axis=1)

xgtrain = xgb.DMatrix(train_data, label=train_target )
xgtest = xgb.DMatrix(test_data, label=test_target)

# %%
params = {
    'objective':'binary:logistic',
    'max_depth':3,
    'silent':1,
    'eta':0.4
}
params['eval_metric'] = ['error', 'auc']

num_rounds = 50

watchlist  = [(xgtest,'test'), (xgtrain,'train')] # native interface only
bst = xgb.train(params, xgtrain, num_rounds, watchlist, early_stopping_rounds=5)
print("Best train score: {}".format(bst.best_score))
print("Best iteration: {}".format(bst.best_iteration))
print("Best number of trees limit: {}".format(bst.best_ntree_limit))
# Out:
# [0]	test-error:0.066044	test-auc:0.759422	train-error:0.064352	train-auc:0.774639
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 5 rounds.
# [1]	test-error:0.065844	test-auc:0.795846	train-error:0.063543	train-auc:0.807917
# [2]	test-error:0.065822	test-auc:0.800135	train-error:0.063724	train-auc:0.812257
# [3]	test-error:0.065644	test-auc:0.806834	train-error:0.063867	train-auc:0.82011
# [4]	test-error:0.065333	test-auc:0.810609	train-error:0.06361	train-auc:0.823283
# [5]	test-error:0.0654	test-auc:0.815202	train-error:0.063505	train-auc:0.827669
# [6]	test-error:0.065489	test-auc:0.823691	train-error:0.063524	train-auc:0.838189
# [7]	test-error:0.065311	test-auc:0.833754	train-error:0.063324	train-auc:0.846266
# [8]	test-error:0.065133	test-auc:0.835565	train-error:0.063	train-auc:0.848362
# [9]	test-error:0.065378	test-auc:0.83824	train-error:0.062695	train-auc:0.851577
# [10]	test-error:0.065311	test-auc:0.83971	train-error:0.062638	train-auc:0.853403
# [11]	test-error:0.065244	test-auc:0.842097	train-error:0.062571	train-auc:0.856005
# [12]	test-error:0.065333	test-auc:0.843019	train-error:0.062533	train-auc:0.857033
# [13]	test-error:0.065133	test-auc:0.843343	train-error:0.0624	train-auc:0.857823
# [14]	test-error:0.0652	test-auc:0.844112	train-error:0.062467	train-auc:0.858738
# [15]	test-error:0.065133	test-auc:0.84502	train-error:0.062286	train-auc:0.859937
# [16]	test-error:0.065156	test-auc:0.846263	train-error:0.062095	train-auc:0.861281
# [17]	test-error:0.065111	test-auc:0.847523	train-error:0.061971	train-auc:0.862611
# [18]	test-error:0.065111	test-auc:0.84845	train-error:0.062086	train-auc:0.863414
# [19]	test-error:0.065044	test-auc:0.848653	train-error:0.062067	train-auc:0.863929
# [20]	test-error:0.064978	test-auc:0.848714	train-error:0.062019	train-auc:0.86412
# [21]	test-error:0.0648	test-auc:0.849038	train-error:0.061962	train-auc:0.864635
# [22]	test-error:0.064778	test-auc:0.849353	train-error:0.061962	train-auc:0.865003
# [23]	test-error:0.064844	test-auc:0.849727	train-error:0.06199	train-auc:0.865777
# [24]	test-error:0.064778	test-auc:0.84979	train-error:0.061914	train-auc:0.866031
# [25]	test-error:0.064667	test-auc:0.849984	train-error:0.061905	train-auc:0.866212
# [26]	test-error:0.064911	test-auc:0.850307	train-error:0.061914	train-auc:0.866828
# [27]	test-error:0.064778	test-auc:0.85038	train-error:0.0618	train-auc:0.86693
# [28]	test-error:0.064689	test-auc:0.850535	train-error:0.061771	train-auc:0.867067
# [29]	test-error:0.0648	test-auc:0.850645	train-error:0.061514	train-auc:0.86722
# [30]	test-error:0.064689	test-auc:0.850801	train-error:0.06161	train-auc:0.867535
# [31]	test-error:0.064756	test-auc:0.850844	train-error:0.061543	train-auc:0.868009
# [32]	test-error:0.064578	test-auc:0.850802	train-error:0.061419	train-auc:0.868354
# [33]	test-error:0.0646	test-auc:0.850887	train-error:0.061248	train-auc:0.868524
# [34]	test-error:0.064556	test-auc:0.851126	train-error:0.061143	train-auc:0.869185
# [35]	test-error:0.064511	test-auc:0.851352	train-error:0.060867	train-auc:0.869376
# [36]	test-error:0.0644	test-auc:0.851378	train-error:0.060819	train-auc:0.869826
# [37]	test-error:0.064378	test-auc:0.8514	train-error:0.060743	train-auc:0.870095
# [38]	test-error:0.0644	test-auc:0.851882	train-error:0.060686	train-auc:0.870566
# [39]	test-error:0.0644	test-auc:0.852003	train-error:0.06059	train-auc:0.870874
# [40]	test-error:0.064333	test-auc:0.852118	train-error:0.060533	train-auc:0.871028
# [41]	test-error:0.064467	test-auc:0.852368	train-error:0.060514	train-auc:0.871329
# [42]	test-error:0.064289	test-auc:0.852457	train-error:0.0604	train-auc:0.871526
# [43]	test-error:0.064156	test-auc:0.852259	train-error:0.0604	train-auc:0.871844
# [44]	test-error:0.064133	test-auc:0.852326	train-error:0.060371	train-auc:0.871966
# [45]	test-error:0.064044	test-auc:0.852352	train-error:0.060381	train-auc:0.871992
# [46]	test-error:0.064156	test-auc:0.852349	train-error:0.06021	train-auc:0.872093
# [47]	test-error:0.064244	test-auc:0.852357	train-error:0.060086	train-auc:0.87233
# [48]	test-error:0.064311	test-auc:0.852449	train-error:0.060152	train-auc:0.872734
# [49]	test-error:0.064267	test-auc:0.852306	train-error:0.060067	train-auc:0.87287
# Best train score: 0.87287
# Best iteration: 49
# Best number of trees limit: 50

# %%
bst.save_model('featMap.txt')
trees_dump = bst.get_dump(fmap='featMap.txt', with_stats=True)
xgb.plot_importance(bst, importance_type='gain', xlabel='Gain')

# %%
seed = 10000
num_rounds = 10
params1 = {
    'objective':'binary:logistic',
    'max_depth':5,
    'silent':1,
    'eta':0.4
}
hist = xgb.cv(params1, xgtrain, num_rounds, nfold=10, metrics={'auc'}, seed=seed)
hist

# %%
y_test_preds = (bst.predict(xgb.DMatrix(test_data)) > 0.5).astype('int')
pd.crosstab(
    pd.Series(test_target, name='Actual'),
    pd.Series(y_test_preds, name='Predicted'),
    margins=True
)
# Out:
# Predicted    0.0  1.0    All
# Actual
# 0.0        12301  243  12544
# 1.0          836   23    859
# All        13137  266  13403

# %%
print('Accuracy: {0:.2f}'.format(accuracy_score(test_target, y_test_preds)))
print('Precision: {0:.2f}'.format(precision_score(test_target, y_test_preds)))
print('Recall: {0:.2f}'.format(recall_score(test_target, y_test_preds)))
